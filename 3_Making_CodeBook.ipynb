# %% [markdown]
# ## Making CodeBook

# %%
import pandas as pd
import numpy as np
from pyclustering.cluster import kmeans
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer
from pyclustering.utils.metric import distance_metric, type_metric
import matplotlib.pyplot as plt
import random

# %%
random.seed(42)

# %%
Code_Book_dir = r".\data\code_book"
Actions_dir = r".\data\actions_txt"
model_path = r".\model"

# %%
def cosine_distance(x1, x2):
    if len(x1.shape) == 1:
        return 1 - np.dot(x1, x2) / (np.linalg.norm(x1) * np.linalg.norm(x2))
    else:
        return 1 - np.sum(np.multiply(x1, x2), axis=1) / (np.linalg.norm(x1, axis=1) * np.linalg.norm(x2, axis=1))

# %% [markdown]
# Making CodeBook from Action vectors

# %% [markdown]
# ### read action vectors in ALL2020 (created in 2_train_fastText)

# %%
# read csv file as DataFrame: ALL-2020 action vectors
all20_action_vectors = pd.read_csv(Code_Book_dir+r"\for_CodeBook_ALL-2020.csv",index_col=0)
all20_action_vectors_df = all20_action_vectors[~all20_action_vectors.index.isnull()]
# Out:
# Index(['Om NsNm PPsGNm Nm Nm Nl',
#        'NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPNsNm NsEmPPm NsNm NsNNsPl',
#        'NmPmNmPl', 'CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl',
#        'OsNNNNNNNNNNNN_ NNNNNNl', 'OsJsNsNNNNsNNN_ NNsNNNNmPl', 'NsNsNmCl',
#        'OsNNNNNNNsNNNN_ NNNNsNNNNNNNNNs_ C', 'OsNNNNNNNNNNNm_ NNNNNNNNNPPsC',
#        'OsC',
#        ...
#        'OsJsPsPl', 'NsNNl', 'OsNNNNsNNNNNsN_ NNl',
#        'OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_ AmN', 'OsNl', 'NmN',
#        'OsJ', 'OmNPNNNNl', 'N', 'OsNsNsOsC'],
#       dtype='object', length=19978)

# %%
# dorp dupuricate
dd_action_vectors_df = all20_action_vectors_df.drop_duplicates()
dd_action_vectors_df
# Out:
#                                                            0         1  \
# Om NsNm PPsGNm Nm Nm Nl                            -0.083315  0.027285
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.085222  0.062409
# NmPmNmPl                                           -0.001252  0.048336
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.086041  0.019689
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.022943 -0.013644
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                 0.032805  0.009897
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.010887 -0.092232
# NmN                                                -0.034567  0.094419
# OmNPNNNNl                                          -0.111154 -0.013637
# OsNsNsOsC                                           0.105405 -0.032733
#
#                                                            2         3  \
# Om NsNm PPsGNm Nm Nm Nl                            -0.091133 -0.164854
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.060711 -0.156039
# NmPmNmPl                                           -0.081426 -0.118651
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.121803 -0.088498
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.027153  0.035683
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.105408 -0.151008
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.207548 -0.087784
# NmN                                                -0.093011 -0.125209
# OmNPNNNNl                                          -0.143043 -0.184279
# OsNsNsOsC                                          -0.324203 -0.243005
#
#                                                            4         5  \
# Om NsNm PPsGNm Nm Nm Nl                             0.064209  0.010463
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.143463  0.062358
# NmPmNmPl                                            0.155995  0.030430
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.113025  0.135193
# OsNNNNNNNNNNNN_ NNNNNNl                             0.010916  0.117197
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                 0.014324  0.071617
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.076943  0.190761
# NmN                                                 0.028906  0.235931
# OmNPNNNNl                                           0.035013 -0.123326
# OsNsNsOsC                                           0.161674  0.148080
#
#                                                            6         7  \
# Om NsNm PPsGNm Nm Nm Nl                            -0.073172 -0.012765
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.092578  0.028540
# NmPmNmPl                                           -0.156981  0.131601
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.001805 -0.018339
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.132012  0.047194
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.021123  0.054687
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.022261  0.073074
# NmN                                                -0.027935  0.045696
# OmNPNNNNl                                           0.094357  0.052194
# OsNsNsOsC                                           0.014040  0.091676
#
#                                                            8         9  ...  \
# Om NsNm PPsGNm Nm Nm Nl                            -0.007444  0.011287  ...
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.002809  0.022281  ...
# NmPmNmPl                                            0.112661  0.218220  ...
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.020624 -0.036749  ...
# OsNNNNNNNNNNNN_ NNNNNNl                             0.091197  0.015513  ...
# ...                                                      ...       ...  ...
# OsNNNNsNNNNNsN_ NNl                                -0.067214 -0.020708  ...
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.199411  0.104993  ...
# NmN                                                -0.111846  0.088905  ...
# OmNPNNNNl                                           0.124429 -0.046374  ...
# OsNsNsOsC                                           0.119905 -0.097461  ...
#
#                                                           90        91  \
# Om NsNm PPsGNm Nm Nm Nl                            -0.107897 -0.073005
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.053042 -0.080878
# NmPmNmPl                                           -0.124072 -0.037887
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.050097  0.018320
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.090381 -0.053275
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                 0.007773  0.093791
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.027416 -0.211887
# NmN                                                -0.082561  0.013961
# OmNPNNNNl                                          -0.085865 -0.092282
# OsNsNsOsC                                          -0.022109 -0.140505
#
#                                                           92        93  \
# Om NsNm PPsGNm Nm Nm Nl                             0.075700  0.155220
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.074375  0.076794
# NmPmNmPl                                            0.115666 -0.003857
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.050024 -0.101317
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.004023  0.023799
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.068032 -0.009380
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.141112  0.082509
# NmN                                                 0.121087  0.068903
# OmNPNNNNl                                          -0.094542  0.199450
# OsNsNsOsC                                          -0.003203  0.035401
#
#                                                           94        95  \
# Om NsNm PPsGNm Nm Nm Nl                             0.015333  0.142523
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.004816  0.072865
# NmPmNmPl                                           -0.115063  0.205928
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.000379  0.120827
# OsNNNNNNNNNNNN_ NNNNNNl                             0.038674  0.200529
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.030452  0.148177
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.045099  0.201910
# NmN                                                 0.022390  0.082786
# OmNPNNNNl                                           0.056740  0.155743
# OsNsNsOsC                                          -0.012084  0.095533
#
#                                                           96        97  \
# Om NsNm PPsGNm Nm Nm Nl                             0.000623  0.224716
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.004450  0.134688
# NmPmNmPl                                            0.190411  0.182133
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.036668  0.060999
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.082019  0.076598
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.003794  0.061818
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.030373  0.091811
# NmN                                                 0.272306  0.144575
# OmNPNNNNl                                          -0.084794 -0.062913
# OsNsNsOsC                                          -0.020155  0.061608
#
#                                                           98        99
# Om NsNm PPsGNm Nm Nm Nl                             0.035070  0.038896
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.058899 -0.010879
# NmPmNmPl                                           -0.011436 -0.114292
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.035802  0.004098
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.055057  0.058366
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.056901  0.019434
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.072421  0.052775
# NmN                                                -0.104529 -0.064873
# OmNPNNNNl                                          -0.031897  0.030142
# OsNsNsOsC                                          -0.027681  0.150864
#
# [14015 rows x 100 columns]

# %% [markdown]
# ### k-means++ clustreing (dist=cosine similarity)

# %%
for k in [10,50,100,200,300]:
    # k == the number of centroids
    labels_list = [0* j  for j in range(len(dd_action_vectors_df))]
    print(k)
    X =dd_action_vectors_df.values
    initial_centers = kmeans_plusplus_initializer(X, k,random_state=42).initialize()
    s_pc_km = kmeans.kmeans(X, initial_centers, metric=distance_metric(type_metric.USER_DEFINED, func=cosine_distance))
    s_pc_km.process()
    s_cent_df = pd.DataFrame(s_pc_km.get_centers()) 
    labels = s_pc_km.get_clusters()
    s_cent_df.to_csv(Code_Book_dir+r"\CodeBook_k{}.csv".format(k))
    

    for num in range(k):
        label_k = labels[num]
        for one_label in label_k:
            #print(one_label)
            labels_list[one_label] = num
    s_cluster_df = pd.DataFrame(labels_list,index=dd_action_vectors_df.index,columns=["cluster"]) 
    #print(len(s_cluster_df))
    #print(s_cluster_df)
    s_cluster_df.to_csv(Code_Book_dir+r"\Actions_clusternum_k{}.csv".format(k))
# Out:
# 10
# 50
# 100
# 200
# 300

# %% [markdown]
# ### with A-2020 and D-2020

# %% [markdown]
# to compare the F1-score of at-risk prediction, actions in A-2020 and D-2020 also clustring

# %%
# A-2020
a20_action_vectors_df = pd.read_csv(Code_Book_dir+r"\for_CodeBook_A-2020.csv",index_col=0)
print(len(a20_action_vectors_df))
a20_action_vectors_df.index.name = "action"
a20_action_vectors_df = a20_action_vectors_df.reset_index()
dd_action_vectors_df = a20_action_vectors_df.drop_duplicates("action")
dd_action_vectors_df = dd_action_vectors_df.set_index("action")
dd_action_vectors_df = dd_action_vectors_df[~dd_action_vectors_df.index.isnull()]
dd_action_vectors_df
# Out:
# 5298
#                                                            0         1  \
# action
# Om NsNm PPsGNm Nm Nm Nl                            -0.083315  0.027285
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.085222  0.062409
# NmPmNmPl                                           -0.001252  0.048336
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.086041  0.019689
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.022943 -0.013644
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                   -0.022945  0.030448
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN...  0.026740  0.072951
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN... -0.040106  0.073957
# OsNmNmNNsNNsNs_ NNNl                                0.015661  0.005435
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_...  0.019225  0.044494
#
#                                                            2         3  \
# action
# Om NsNm PPsGNm Nm Nm Nl                            -0.091133 -0.164854
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.060711 -0.156039
# NmPmNmPl                                           -0.081426 -0.118651
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.121803 -0.088498
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.027153  0.035683
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                   -0.182214 -0.233402
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN... -0.133955 -0.170351
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN... -0.043855 -0.074922
# OsNmNmNNsNNsNs_ NNNl                               -0.182366 -0.165771
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_... -0.034163 -0.095906
#
#                                                            4         5  \
# action
# Om NsNm PPsGNm Nm Nm Nl                             0.064209  0.010463
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.143463  0.062358
# NmPmNmPl                                            0.155995  0.030430
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.113025  0.135193
# OsNNNNNNNNNNNN_ NNNNNNl                             0.010916  0.117197
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                    0.069278  0.099901
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN...  0.060595  0.130018
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN...  0.011450  0.054285
# OsNmNmNNsNNsNs_ NNNl                                0.099918  0.134430
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_... -0.005021  0.079248
#
#                                                            6         7  \
# action
# Om NsNm PPsGNm Nm Nm Nl                            -0.073172 -0.012765
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.092578  0.028540
# NmPmNmPl                                           -0.156981  0.131601
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.001805 -0.018339
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.132012  0.047194
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                   -0.047653  0.044064
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN... -0.049711  0.058186
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN...  0.034686 -0.041439
# OsNmNmNNsNNsNs_ NNNl                               -0.043640  0.101922
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_... -0.086335  0.077171
#
#                                                            8         9  ...  \
# action                                                                  ...
# Om NsNm PPsGNm Nm Nm Nl                            -0.007444  0.011287  ...
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.002809  0.022281  ...
# NmPmNmPl                                            0.112661  0.218220  ...
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.020624 -0.036749  ...
# OsNNNNNNNNNNNN_ NNNNNNl                             0.091197  0.015513  ...
# ...                                                      ...       ...  ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                    0.000494 -0.000356  ...
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN... -0.036866  0.019354  ...
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN...  0.029705 -0.034520  ...
# OsNmNmNNsNNsNs_ NNNl                                0.023108 -0.020162  ...
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_...  0.021377 -0.012138  ...
#
#                                                           90        91  \
# action
# Om NsNm PPsGNm Nm Nm Nl                            -0.107897 -0.073005
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN... -0.053042 -0.080878
# NmPmNmPl                                           -0.124072 -0.037887
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                  0.050097  0.018320
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.090381 -0.053275
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                   -0.022333 -0.071132
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN...  0.077395  0.018144
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN...  0.022608 -0.075409
# OsNmNmNNsNNsNs_ NNNl                               -0.028014 -0.027458
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_...  0.022921 -0.078702
#
#                                                           92        93  \
# action
# Om NsNm PPsGNm Nm Nm Nl                             0.075700  0.155220
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.074375  0.076794
# NmPmNmPl                                            0.115666 -0.003857
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.050024 -0.101317
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.004023  0.023799
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                    0.085195  0.037002
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN...  0.020402 -0.026232
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN...  0.107405  0.052944
# OsNmNmNNsNNsNs_ NNNl                               -0.027832  0.070674
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_...  0.081756  0.023772
#
#                                                           94        95  \
# action
# Om NsNm PPsGNm Nm Nm Nl                             0.015333  0.142523
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.004816  0.072865
# NmPmNmPl                                           -0.115063  0.205928
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.000379  0.120827
# OsNNNNNNNNNNNN_ NNNNNNl                             0.038674  0.200529
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                    0.022098  0.038664
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN... -0.007357  0.079239
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN... -0.048155  0.084052
# OsNmNmNNsNNsNs_ NNNl                               -0.017013  0.056482
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_...  0.015936  0.058683
#
#                                                           96        97  \
# action
# Om NsNm PPsGNm Nm Nm Nl                             0.000623  0.224716
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.004450  0.134688
# NmPmNmPl                                            0.190411  0.182133
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.036668  0.060999
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.082019  0.076598
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                   -0.002616  0.044054
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN...  0.046234  0.092458
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN... -0.030083  0.113788
# OsNmNmNNsNNsNs_ NNNl                                0.007803 -0.076248
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_...  0.064277  0.075732
#
#                                                           98        99
# action
# Om NsNm PPsGNm Nm Nm Nl                             0.035070  0.038896
# NNsPNsNNsNmNmNm_ Nm Nm NsNsNm Nm NmNm NsPsNmPPN...  0.058899 -0.010879
# NmPmNmPl                                           -0.011436 -0.114292
# CsOsNNNNNsNNNN_ NNsNNsNNNNsNsN_ Cl                 -0.035802  0.004098
# OsNNNNNNNNNNNN_ NNNNNNl                            -0.055057  0.058366
# ...                                                      ...       ...
# OsNsNsNsNNsNsN_ Nm NsNsNmNNsNsPl                    0.037096  0.018171
# OsNNsNsNm NsNsNsNsNsNsNs_ NNNsNNNsNmNsNNs_ NNNN...  0.024457  0.002764
# PPPPPsPPPPPPPPs_ PPPsPsPPPPPPsP_ PNNNNNNNNNsNNN...  0.025279 -0.009446
# OsNmNmNNsNNsNs_ NNNl                               -0.057701 -0.059410
# NsNNNPsPsNsNsN_ PsNsNsNmNsNNNs_ NNsPsNNNNNNNNN_...  0.012300  0.016492
#
# [4112 rows x 100 columns]

# %%
for k in [100]:
    # k == the number of centroids
    labels_list = [0* j  for j in range(len(dd_action_vectors_df))]
    X =dd_action_vectors_df.values
    initial_centers = kmeans_plusplus_initializer(X, k,random_state=42).initialize()
    s_pc_km = kmeans.kmeans(X, initial_centers, metric=distance_metric(type_metric.USER_DEFINED, func=cosine_distance))
    s_pc_km.process()
    s_cent_df = pd.DataFrame(s_pc_km.get_centers()) 
    labels = s_pc_km.get_clusters()
    s_cent_df.to_csv(Code_Book_dir+r"\CodeBook_k{}_A20.csv".format(k))
    

    for num in range(k):
        label_k = labels[num]
        for one_label in label_k:
            labels_list[one_label] = num
    s_cluster_df = pd.DataFrame(labels_list,index=dd_action_vectors_df.index,columns=["cluster"]) 
    s_cluster_df.to_csv(Code_Book_dir+r"\Actions_clusternum_k{}_A20.csv".format(k))
# Out:
# 100

# %%
# D-2020
d20_action_vectors_df = pd.read_csv(Code_Book_dir+r"\for_CodeBook_D-2020.csv",index_col=0)
print(len(d20_action_vectors_df))
d20_action_vectors_df.index.name = "action"
d20_action_vectors_df = d20_action_vectors_df.reset_index()
dd_action_vectors_df = d20_action_vectors_df.drop_duplicates("action")
dd_action_vectors_df = dd_action_vectors_df.set_index("action")
dd_action_vectors_df = dd_action_vectors_df[~dd_action_vectors_df.index.isnull()]
dd_action_vectors_df
# Out:
# 14681
#                                                            0         1  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                         -0.056120  0.011243
# ONsNNNmC                                            0.128143  0.091796
# ONNl                                                0.090136 -0.004439
# C                                                  -0.000080  0.058199
# Ol                                                  0.041921 -0.006690
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                 0.032805  0.009897
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.010887 -0.092232
# NmN                                                -0.034567  0.094419
# OmNPNNNNl                                          -0.111154 -0.013637
# OsNsNsOsC                                           0.105405 -0.032733
#
#                                                            2         3  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                         -0.114937 -0.157105
# ONsNNNmC                                           -0.084384 -0.026246
# ONNl                                               -0.221449 -0.206280
# C                                                  -0.217938 -0.181461
# Ol                                                 -0.150537 -0.190908
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.105408 -0.151008
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.207548 -0.087784
# NmN                                                -0.093011 -0.125209
# OmNPNNNNl                                          -0.143043 -0.184279
# OsNsNsOsC                                          -0.324203 -0.243005
#
#                                                            4         5  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                          0.125001  0.028277
# ONsNNNmC                                            0.088240  0.213856
# ONNl                                                0.104274  0.171471
# C                                                   0.158777  0.241943
# Ol                                                  0.094964  0.116905
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                 0.014324  0.071617
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.076943  0.190761
# NmN                                                 0.028906  0.235931
# OmNPNNNNl                                           0.035013 -0.123326
# OsNsNsOsC                                           0.161674  0.148080
#
#                                                            6         7  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                         -0.050841 -0.010220
# ONsNNNmC                                            0.024796 -0.164345
# ONNl                                               -0.155033  0.087633
# C                                                  -0.192023  0.059510
# Ol                                                 -0.115994  0.113146
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.021123  0.054687
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.022261  0.073074
# NmN                                                -0.027935  0.045696
# OmNPNNNNl                                           0.094357  0.052194
# OsNsNsOsC                                           0.014040  0.091676
#
#                                                            8         9  ...  \
# action                                                                  ...
# OsNm Nm NsNm PPNNPPm Nm Cl                          0.031883 -0.024166  ...
# ONsNNNmC                                           -0.082999 -0.000498  ...
# ONNl                                               -0.012196 -0.052295  ...
# C                                                   0.096338  0.019425  ...
# Ol                                                  0.055856 -0.044877  ...
# ...                                                      ...       ...  ...
# OsNNNNsNNNNNsN_ NNl                                -0.067214 -0.020708  ...
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.199411  0.104993  ...
# NmN                                                -0.111846  0.088905  ...
# OmNPNNNNl                                           0.124429 -0.046374  ...
# OsNsNsOsC                                           0.119905 -0.097461  ...
#
#                                                           90        91  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                         -0.059501 -0.095077
# ONsNNNmC                                            0.213039 -0.054572
# ONNl                                               -0.084203 -0.141518
# C                                                  -0.000356 -0.068117
# Ol                                                 -0.148956 -0.180957
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                 0.007773  0.093791
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.027416 -0.211887
# NmN                                                -0.082561  0.013961
# OmNPNNNNl                                          -0.085865 -0.092282
# OsNsNsOsC                                          -0.022109 -0.140505
#
#                                                           92        93  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                          0.064098  0.124789
# ONsNNNmC                                            0.017756 -0.072710
# ONNl                                               -0.066331  0.133776
# C                                                   0.084202  0.097068
# Ol                                                  0.057075  0.227519
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.068032 -0.009380
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.141112  0.082509
# NmN                                                 0.121087  0.068903
# OmNPNNNNl                                          -0.094542  0.199450
# OsNsNsOsC                                          -0.003203  0.035401
#
#                                                           94        95  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                          0.008824  0.103760
# ONsNNNmC                                           -0.123637  0.194721
# ONNl                                                0.017587  0.192839
# C                                                  -0.030553  0.314691
# Ol                                                  0.008122  0.264285
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.030452  0.148177
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_...  0.045099  0.201910
# NmN                                                 0.022390  0.082786
# OmNPNNNNl                                           0.056740  0.155743
# OsNsNsOsC                                          -0.012084  0.095533
#
#                                                           96        97  \
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                          0.015823  0.149201
# ONsNNNmC                                           -0.137530  0.106401
# ONNl                                               -0.102663  0.127455
# C                                                  -0.100361  0.255294
# Ol                                                  0.038063  0.345135
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.003794  0.061818
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.030373  0.091811
# NmN                                                 0.272306  0.144575
# OmNPNNNNl                                          -0.084794 -0.062913
# OsNsNsOsC                                          -0.020155  0.061608
#
#                                                           98        99
# action
# OsNm Nm NsNm PPNNPPm Nm Cl                          0.040692  0.036449
# ONsNNNmC                                            0.037278 -0.039177
# ONNl                                               -0.023552  0.047837
# C                                                   0.049929 -0.015132
# Ol                                                  0.014588  0.023465
# ...                                                      ...       ...
# OsNNNNsNNNNNsN_ NNl                                -0.056901  0.019434
# OsNsAsAmNsAsAs_ NsNsAsAsAsAsNs_ AAsAsNsNmNmAsA_... -0.072421  0.052775
# NmN                                                -0.104529 -0.064873
# OmNPNNNNl                                          -0.031897  0.030142
# OsNsNsOsC                                          -0.027681  0.150864
#
# [10128 rows x 100 columns]

# %%
for k in [100]:
    # k == the number of centroids
    labels_list = [0* j  for j in range(len(dd_action_vectors_df))]
    X =dd_action_vectors_df.values
    initial_centers = kmeans_plusplus_initializer(X, k,random_state=42).initialize()
    s_pc_km = kmeans.kmeans(X, initial_centers, metric=distance_metric(type_metric.USER_DEFINED, func=cosine_distance))
    s_pc_km.process()
    s_cent_df = pd.DataFrame(s_pc_km.get_centers()) 
    labels = s_pc_km.get_clusters()
    s_cent_df.to_csv(Code_Book_dir+r"\CodeBook_k{}_D20.csv".format(k))
    

    for num in range(k):
        label_k = labels[num]
        for one_label in label_k:
            #print(one_label)
            labels_list[one_label] = num
    s_cluster_df = pd.DataFrame(labels_list,index=dd_action_vectors_df.index,columns=["cluster"]) 
    s_cluster_df.to_csv(Code_Book_dir+r"\Actions_clusternum_k{}_D20.csv".format(k))
# Out:
# 100
